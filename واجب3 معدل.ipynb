# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# إنشاء DataSet فيه 40 منتج غذائي مع تعليقات
data = {
    "Product": [
        "Rice", "Pasta", "Bread", "Milk", "Cheese",
        "Butter", "Eggs", "Chicken", "Beef", "Fish",
        "Apple", "Banana", "Orange", "Grapes", "Strawberry",
        "Tomato", "Potato", "Onion", "Carrot", "Cucumber",
        "Olive Oil", "Sugar", "Salt", "Honey", "Jam",
        "Coffee", "Tea", "Juice", "Water Bottle", "Soft Drink",
        "Chips", "Biscuits", "Chocolate", "Ice Cream", "Yogurt",
        "Beans", "Lentils", "Flour", "Corn", "Nuts"
    ],
    "Review": [
        "جودة ممتازة وطعم رائع", "سهل الطبخ ويشبع", "طازج ولذيذ",
        "مغذي وصحي", "طعم مميز ويذوب بالفم", "زبدة ناعمة وطبيعية",
        "طازجة ومفيدة", "لحم طري ولذيذ", "جودة ممتازة ولحم طيب",
        "طازج وصحي", "حلوة ولذيذة", "طعم رائع وسهل الأكل",
        "عصير طبيعي منعش", "عنب طازج وحلو", "مذاق شهي ومفيد",
        "خضار طازجة وصحية", "بطاطس لذيذة", "بصل طازج", "جزر مقرمش",
        "خيار طازج وصحي", "زيت طبيعي ممتاز", "سكر نقي", "ملح طبيعي",
        "عسل نقي", "مربى طازجة", "قهوة غنية الطعم", "شاي منعش",
        "عصير طازج", "مياه نظيفة وصحية", "مشروب غازي منعش",
        "مقرمشات لذيذة", "بسكويت طازج", "شوكولاتة لذيذة", "آيس كريم بارد",
        "زبادي مغذي", "فول صحي", "عدس غني بالبروتين", "دقيق طازج",
        "ذرة لذيذة", "مكسرات طازجة"
    ]
}

# تحويل البيانات إلى DataFrame
df = pd.DataFrame(data)

# تقسيم البيانات إلى تدريب واختبار
train, test = train_test_split(df, test_size=0.3, random_state=42)

# عرض النتائج
print("مجموعة التدريب:")
print(train)
print("\nمجموعة الاختبار:")
print(test)
# Out:
# مجموعة التدريب:
#          Product                 Review
# 13        Grapes          عنب طازج وحلو
# 31      Biscuits            بسكويت طازج
# 34        Yogurt             زبادي مغذي
# 8           Beef   جودة ممتازة ولحم طيب
# 17         Onion               بصل طازج
# 24           Jam             مربى طازجة
# 0           Rice  جودة ممتازة وطعم رائع
# 33     Ice Cream          آيس كريم بارد
# 5         Butter     زبدة ناعمة وطبيعية
# 11        Banana    طعم رائع وسهل الأكل
# 1          Pasta        سهل الطبخ ويشبع
# 29    Soft Drink        مشروب غازي منعش
# 21         Sugar                سكر نقي
# 2          Bread             طازج ولذيذ
# 30         Chips          مقرمشات لذيذة
# 36       Lentils      عدس غني بالبروتين
# 3           Milk              مغذي وصحي
# 35         Beans                فول صحي
# 23         Honey                عسل نقي
# 32     Chocolate         شوكولاتة لذيذة
# 10         Apple            حلوة ولذيذة
# 22          Salt              ملح طبيعي
# ...
